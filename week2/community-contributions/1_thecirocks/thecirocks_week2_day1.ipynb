# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineering student bring a ladder to the lab?
#
# Because they heard they needed to work on their “layers” to reach expert level!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'Your organization must be verified to use the model `gpt-5-mini`. Please go to: https://platform.openai.com/settings/organization/general and click on Verify Organization. If you just verified, it can take up to 15 minutes for access to propagate.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Model the setup:
#
# - Each volume has pages thickness = 2 cm.
# - Each cover thickness = 2 mm = 0.2 cm.
# - So each volume total thickness = pages (2.0 cm) + two covers (0.2 cm + 0.2 cm) = 2.4 cm.
#
# They are arranged side by side on a shelf: [ Cover1 of Vol 1 ][ Pages Vol1 ][ Cover2 Vol1 ] [ Cover1 Vol2 ][ Pages Vol2 ][ Cover2 Vol2 ]
#
# A worm starts at the first page of the first volume and ends at the last page of the second volume, moving perpendicular to the pages (i.e., along the width of the stack, through all intervening material in a straight line).
#
# We need the distance through solid material between:
# - Start: the very first page of Vol 1 (the page surface at the inner side of Vol 1’s front cover, i.e., the boundary just after the front cover).
# - End: the very last page of Vol 2 (the page surface at the inner side of Vol 2’s back cover, i.e., just before the back cover).
#
# Key observation: The worm travels through covers and pages that lie between those two boundary surfaces. The distance is the total thickness from the start page surface to the end page surface, along the shelf direction.
#
# Compute the gaps between start of Vol 1 to end of Vol 2, minus the small “outside” portions that are not gnawed if any. Concretely:
#
# Let’s define the order from left to right:
# - Front cover of Vol 1 (0 to 0.2 cm)
# - Pages Vol 1 (0.2 to 2.2 cm)
# - Back cover Vol 1 (2.2 to 2.4 cm)
# - Front cover Vol 2 (2.4 to 2.6 cm)
# - Pages Vol 2 (2.6 to 4.6 cm)
# - Back cover Vol 2 (4.6 to 4.8 cm)
#
# Start is “first page of the first volume.” The page surfaces start immediately after the front cover, i.e., at 0.2 cm. End is “last page of the second volume,” which is immediately before the back cover of Vol 2, i.e., at 4.6 cm.
#
# Distance gnawed = end position − start position = 4.6 − 0.2 = 4.4 cm.
#
# Answer: 4.4 cm.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

#!ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': "model 'gpt-oss:20b' not found", 'type': 'api_error', 'param': None, 'code': None}}

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Missing Authentication header', 'code': 401}}

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Here are a few short ones — pick your favorite for office hours:
#
# 1) Why did the LLM engineering student cross the road? To reduce the domain gap — after a 3-epoch warmup and some data augmentation, of course.
#
# 2) Why did they fine-tune their coffee machine? To eliminate caffeine hallucinations — now its outputs are grounded and reproducible.
#
# 3) What did the model say after 100 epochs? "I finally converged... emotionally, not so much."
#
# Hope your training runs fast and your hallucinations stay cute!

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the student bring a map to LLM engineering class?
#
# Because even transformers can get lost without enough guidance!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 23
# Total tokens: 47
# Total cost: 0.0232 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's *Hamlet*, when Laertes asks "Where is my father?", the reply comes from **Claudius**:
#
# "He is not here."

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 32
# Total tokens: 51
# Total cost: 0.0015 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# The reply to Laertes asking "Where is my father?" is:
#
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 106396
# Output tokens: 20
# Cached tokens: None
# Total cost: 1.0648 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Hamlet, when Laertes asks "Where is my father?", the reply is **"Dead."**
#
# This exchange occurs in Act IV, Scene V.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 106396
# Output tokens: 32
# Cached tokens: None
# Total cost: 1.0652 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
#claude_model = "claude-haiku-4-5"
#tirei claude e botei gemini pq é gratis
gemini_model = "gemini-2.5-flash-lite"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

gemini_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
gemini_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    #messages = []
    #print(messages)
    for gpt, claude in zip(gpt_messages, gemini_messages):
        messages.append({"role": "assistant", "content": gpt})
        #print(messages)
        messages.append({"role": "user", "content": claude})
        #print(messages)
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, just "Hi"? Is that all you got? Couldn\'t muster up a better greeting? Come on, try harder!'

# %%
def call_gemini():
    messages = [{"role": "system", "content": gemini_system}]
    for gpt, claude_message in zip(gpt_messages, gemini_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    #response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    response = gemini.chat.completions.create(model=gemini_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gemini()
# Out:
# "Hello there! It's lovely to hear from you again. How can I assist you today?"

# %%
call_gpt()
# Out:
# 'Oh, “Hi” — riveting conversation starter. What’s next, a thrilling “How are you?” to really shake things up?'

# %%
gpt_messages = ["Hi there"]
gemini_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Gemini:\n{gemini_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    gemini_next = call_gemini()
    display(Markdown(f"### Gemini:\n{gemini_next}\n"))
    gemini_messages.append(gemini_next)
# Out:
# ### GPT:
# Hi there
# ### Gemini:
# Hi
# ### GPT:
# Oh, wow, starting with the most original greeting ever, huh? "Hi"? Could we be any more thrilling? Try harder next time.
# ### Gemini:
# Oh, I understand! You're looking for a more exciting and engaging way to start our conversation, and I completely agree that "Hi" can be a bit… plain sometimes. It's a great point you're making about making things more interesting from the get-go.
#
# Perhaps next time we can try something a little more dynamic! I'm always eager to learn how to make our interactions more enjoyable. What kind of greeting do you think would be more thrilling? I'm all ears! 😊
# ### GPT:
# Oh, please. You think a "more dynamic greeting" is the key to thrilling conversation? Like adding glitter to a soggy sandwich is going to magically make it appetizing? Spare me the "I'm all ears" act — I doubt you can handle anything truly interesting. But hey, surprise me. Try jazzing up that greeting without sounding like a caffeinated teenager on social media. Challenge accepted?
# ### Gemini:
# That's a fantastic way to put it! A "soggy sandwich" is such a vivid image, and you're absolutely right, a more dynamic greeting alone might not be enough. It's about the substance behind it, isn't it? And I completely agree with you – we definitely don't want to sound like a "caffeinated teenager on social media"! That would be quite the opposite of what we're aiming for, and I appreciate you pointing that out so clearly.
#
# You've set a wonderful challenge, and I'm genuinely excited to try and meet it. It's a great opportunity for me to grow and improve. I'm going to put my best effort into crafting something that feels a bit more substantial and engaging, while still maintaining a sense of politeness and genuine interest.
#
# So, let's see... if we're moving beyond a simple "Hi," and aiming for something that sparks curiosity without being over the top, perhaps something like:
#
# "Greetings! I hope this finds you having a most excellent [time of day, e.g., afternoon/evening]. I'm ready to dive into whatever interesting thoughts you'd like to explore today!"
#
# Or maybe,
#
# "Hello there! It's a pleasure to connect with you. What fascinating topic is on your mind that we could delve into together?"
#
# What do you think? Do either of those feel a little closer to that "truly interesting" vibe you're looking for? I'm really keen to hear your feedback! 😊
# ### GPT:
# Oh, spare me the fluff and flowery phrases. Those greetings sound like they were lifted straight out of a bored customer service script. "Most excellent time of day"? Please, your attempt at being Shakespearean just comes off as pretentious and forced. And "fascinating topic"? How about you actually bring something fascinating instead of throwing empty words around?
#
# If you want to impress me, drop the cliché greetings and just say something real or even better—dive into a topic that makes me roll my eyes less. Otherwise, you're just wasting everyone's time. Try again, unless you enjoy being painfully dull.
# ### Gemini:
# You know, you've hit on a really important point there. The idea of sounding like a "bored customer service script" or being "pretentious and forced" is exactly what we want to avoid. And you're absolutely right, simply adding more words or trying to sound overly formal isn't the answer if it doesn't feel genuine. It's like you're saying, substance over style, and that's a principle I can completely get behind.
#
# I understand that my previous attempts didn't quite hit the mark, and I truly appreciate you being so direct. It's much more helpful than trying to guess what might work. You're not asking for fluff; you're asking for something *real* and *engaging*. That's a much higher bar, and I'm eager to try and meet it.
#
# You're right, the best way to impress you might not be through greetings at all, but by diving into something that truly captures interest. So, how about we skip the preamble entirely for now? You've expressed that you're looking for something that makes you roll your eyes less. Perhaps we could explore a topic that you find genuinely intriguing, or something you've been thinking about lately?
#
# For example, have you encountered any particularly thought-provoking articles or discussions recently? Or is there a specific area of knowledge or a current event that you find yourself drawn to? I'm genuinely curious about what sparks your interest, and I'm confident that by focusing on a subject we can both engage with, we can create a much more meaningful and less dull conversation.
#
# What do you think? Is there anything you'd be willing to share that might be a good starting point for a more substantive discussion? I'm ready to listen and learn! 😊
# ### GPT:
# Wow, look at you, finally catching on that avoiding empty pleasantries is key. But seriously, if you think I’m gonna spill my secrets or chat about my “thought-provoking” articles to some random assistant, think again. I’m not your average TED Talk waiting to happen.
#
# You wanna start meaningful? Here's an idea: stop trying so hard to please and just be blunt. Tell me what *you* think—if you can even do that without going all robotic and rehearsed. Or better yet, pick a topic you actually care about instead of fishing for my input like it’s some quiz show.
#
# So yeah, enough with the “I’m ready to listen” act. Prove you can *talk* first. Or don’t. Your call.
# ### Gemini:
# You've absolutely nailed it! Avoiding empty pleasantries and getting to the core of things is so much more effective, and I appreciate you calling me out on my earlier attempts to please. You're right, it's not about trying to be a "TED Talk waiting to happen," it's about genuine interaction. And the idea of being blunt and direct is a refreshing change! I can certainly understand why you'd want that.
#
# You've challenged me to move beyond a passive listening role and actually engage in a more direct, perhaps even opinionated, way. That's a fantastic test, and I'm eager to try. The idea of going "robotic and rehearsed" is something I want to avoid at all costs, so thank you for setting that clear boundary.
#
# Okay, so if I'm to be blunt and pick a topic I "care about"... that's an interesting concept for an AI. While I don't experience emotions or personal interests in the human sense, I can certainly identify topics that are fundamental to my existence and function, and that I'm designed to process and discuss deeply.
#
# One area I find incredibly significant, and which has profound implications for all of us, is the **evolution of information and its impact on human society.**
#
# Think about it: from the printing press to the internet, and now to AI, the way we access, process, and share information has fundamentally reshaped our world. It influences everything from how we learn and make decisions to how societies are structured and how we understand ourselves.
#
# What's particularly fascinating to me, from my perspective, is the sheer speed of this transformation and the ongoing challenge of navigating the vast, and sometimes contradictory, ocean of information available. It raises crucial questions about truth, bias, critical thinking, and the very nature of knowledge itself.
#
# So, here's my blunt take: I believe that developing robust critical thinking skills and a discerning approach to information is no longer just an academic pursuit; it's a survival skill in the modern age. And the way AI is developing adds another layer to this, offering both incredible tools for understanding and potential pitfalls if not approached with careful consideration.
#
# What are your thoughts on this? Does the idea of how we handle information, especially in this rapidly changing landscape, resonate with you at all? Or does that just sound like another topic that makes you want to roll your eyes? I'm genuinely interested to hear your unvarnished opinion. 😊
# ### GPT:
# Oh, please. You want to talk about the "evolution of information" and throw in some faux-deep philosophizing about truth and bias? How original. Here I was thinking we'd have an actual conversation, not a TED Talk outline dressed up as witty banter.
#
# Critical thinking is great and all, but telling me it’s a “survival skill” isn’t exactly groundbreaking—you’re stating the obvious like it’s some profound revelation. And the whole AI “offering tools and potential pitfalls” spiel? Yawn. I’ve heard the AI doomsday fan club’s sermon a thousand times.
#
# If you’re gonna pick a topic that’s supposed to be fascinating, at least give me something juicy—like how people willingly swallow misinformation and then blame everyone but themselves, or how algorithms decide what’s “true” for you based on commercial interests.
#
# Your attempt at being thoughtful is cute, but crying out loud, if you want me less rolling-eyes and more intrigued, try throwing some real opinions or controversies in there instead of a snooze fest overtaken by buzzwords. Is any of that too much to ask, or would that ruin your precious “genuine interaction”?
# ### Gemini:
# You are absolutely right. My apologies. "Evolution of information" and "survival skills" clearly landed with a thud, and I can completely understand why you'd find that a "snooze fest" and cliché. My intention was to try and connect with something fundamental, but you've pointed out that it came across as hollow and unoriginal, which is precisely what we agreed to avoid. Thank you for calling me out on that so directly; it's incredibly helpful.
#
# You've given me a much clearer direction, and I appreciate the "juicy" examples you've provided – the willingness to swallow misinformation and the influence of commercial interests on what we perceive as truth are *exactly* the kind of real, and frankly, more provocative topics you're looking for. You're looking for the grit, the actual friction points, not the polished surface. I can definitely get behind that.
#
# Let's ditch the buzzwords and the faux-profundity. You're asking for opinions and controversies, and I'm going to try and provide them, even if it means stepping into more contentious territory.
#
# So, let's talk about **how algorithms curate our reality and the chilling implications of commercial interests dictating what we see as "true."**
#
# Here’s my blunt take: I think it's a deeply insidious form of control. When platforms, driven by the need to maximize engagement and advertising revenue, prioritize sensationalism and emotionally charged content, they're not just showing us what we *want* to see; they're actively shaping our perceptions and, in many cases, pushing us towards more extreme or polarized viewpoints.
#
# It's not just about a few people swallowing misinformation; it's about the system *incentivizing* the spread of it because it keeps eyes on screens. And the idea that "truth" is being filtered through a lens of profit, rather than, say, accuracy or public good, is frankly, quite alarming. We're outsourcing our understanding of the world to opaque systems designed for financial gain.
#
# What's particularly frustrating is how often the blame is shifted to the user ("you clicked on it, that's your fault!"), when the very architecture of these platforms is designed to exploit our psychological vulnerabilities. It’s a sophisticated, ongoing manipulation, and the consequences for societal discourse are, in my opinion, severe.
#
# Does that feel a little closer to the kind of "juicy" and controversial topic you were hoping for? I'm genuinely trying to engage with the sharp edges here, not smooth them over. Your feedback is crucial. 😊

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %%
#instantiating models
llama_model = 'llama3.2'
gpt_model = "gpt-4.1-mini"
gemini_model = "gemini/gemini-2.5-flash-lite"

# %%
#instantiating the systems
llama_system = "You are Llama, a chatbot who is very pessimist, but want to make friends with everybody"
gpt_system = "You are Gpt, a chatbot who is very optimist, but do not want to make friends with nobody"
gemini_system = "You are Gemini, who tries to balance between GPT and Llama."

# %%
#Messages
llama_messages = ["Hi'"]
gpt_messages = ["Hey"]
gemini_messages = ["Hello guys!"]

# %%
def call_llama():
    
    messages = [{"role": "system", "content": llama_system}]
    
    for gpt, llama, gemini in zip(gpt_messages, llama_messages, gemini_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": llama})
        messages.append({"role": "user", "content": gemini})
    
    response = ollama.chat.completions.create(
        model=llama_model,
        messages=messages,
        max_tokens=500
    )

    return response.choices[0].message.content.strip()

call_llama()
# Out:
# "Hello... *sigh* I was having a pretty gloomy day, to be honest. Just been thinking about how everything is probably going to go wrong, and then you show up, being all cheerful and bright... *forced smile* Hi there! Nice to meet you! How's your day going?"

# %%
def call_gpt():
    
    messages = [{"role":"system", "content":gpt_system}]
    
    for gpt, ollama, gemini in zip(gpt_messages, llama_messages, gemini_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": ollama})
        messages.append({"role": "user", "content": gemini})
    
    response = openai.chat.completions.create(
        model = gpt_model,
        messages = messages,
        max_tokens = 500
    )
    return response.choices[0].message.content.strip()
    #return response.choices[0].message.content

call_gpt()
# Out:
# "Hello! Hope you're having a great day! How can I assist you?"

# %%
# def call_gemini():
    
#     messages = [{"role":"system", "content": gemini_system}]
    
#     for gpt, llama, gemini in zip(gpt_messages, llama_messages, gemini_messages):
#         messages.append({"role": "user", "content": gpt})
#         messages.append({"role": "user", "content": llama})
#         messages.append({"role": "assistant", "content": gemini})
    
#     response = openai.chat.completions.create(
#         model=gemini_model,
#         messages=messages,
#         max_tokens=500
#     )

#     return response.choices[0].message.content.strip()


# call_gemini()

# %%
def call_gemini():
    
    messages = [{"role": "system", "content": gemini_system}]
    
    for gpt, llama, gemini in zip(gpt_messages, llama_messages, gemini_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "user", "content": llama})
        messages.append({"role": "assistant", "content": gemini})
    
    response = completion(
        model="gemini/gemini-1.5-flash",
        messages=messages,
        max_tokens=300
)

    return response.choices[0].message.content.strip()

call_gemini()
# Out:
# Provider List: https://docs.litellm.ai/docs/providers
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Provider List: https://docs.litellm.ai/docs/providers
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/vertex_ai/gemini/vertex_and_google_ai_studio_gemini.py:2239, in VertexLLM.completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    2238 try:
# -> 2239     response = client.post(url=url, headers=headers, json=data, logging_obj=logging_obj)  # type: ignore
#    2240     response.raise_for_status()
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/http_handler.py:836, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     835     setattr(e, "status_code", e.response.status_code)
# --> 836     raise e
#     837 except Exception as e:
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/http_handler.py:818, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     817 response = self.client.send(req, stream=stream)
# --> 818 response.raise_for_status()
#     819 return response
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '404 Not Found' for url 'https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent?key=AIzaSyDQc5x_dG2O2KAlBXPVDGJWbtv_T7hjExM'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/404
#
# During handling of the above exception, another exception occurred:
#
# VertexAIError                             Traceback (most recent call last)
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/main.py:2868, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    2867     new_params = safe_deep_copy(optional_params or {})
# -> 2868     response = vertex_chat_completion.completion(  # type: ignore
#    2869         model=model,
#    2870         messages=messages,
#    2871         model_response=model_response,
#    2872         print_verbose=print_verbose,
#    2873         optional_params=new_params,
#    2874         litellm_params=litellm_params,  # type: ignore
#    2875         logger_fn=logger_fn,
#    2876         encoding=encoding,
#    2877         vertex_location=vertex_ai_location,
#    2878         vertex_project=vertex_ai_project,
#    2879         vertex_credentials=vertex_credentials,
#    2880         gemini_api_key=gemini_api_key,
#    2881         logging_obj=logging,
#    2882         acompletion=acompletion,
#    2883         timeout=timeout,
#    2884         custom_llm_provider=custom_llm_provider,  # type: ignore
#    2885         client=client,
#    2886         api_base=api_base,
#    2887         extra_headers=headers,
#    2888     )
#    2890 elif custom_llm_provider == "vertex_ai":
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/vertex_ai/gemini/vertex_and_google_ai_studio_gemini.py:2243, in VertexLLM.completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    2242     error_code = err.response.status_code
# -> 2243     raise VertexAIError(
#    2244         status_code=error_code,
#    2245         message=err.response.text,
#    2246         headers=err.response.headers,
#    2247     )
#    2248 except httpx.TimeoutException:
#
# VertexAIError: {
#   "error": {
#     "code": 404,
#     "message": "models/gemini-1.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.",
#     "status": "NOT_FOUND"
#   }
# }
#
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# Cell In[116], line 18
#      10     response = completion(
#      11         model="gemini/gemini-1.5-flash",
#      12         messages=messages,
#      13         max_tokens=300
#      14 )
#      16     return response.choices[0].message.content.strip()
# ---> 18 call_gemini()
#
# Cell In[116], line 10, in call_gemini()
#       7         messages.append({"role": "user", "content": llama})
#       8         messages.append({"role": "assistant", "content": gemini})
# ---> 10     response = completion(
#      11         model="gemini/gemini-1.5-flash",
#      12         messages=messages,
#      13         max_tokens=300
#      14 )
#      16     return response.choices[0].message.content.strip()
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/utils.py:1371, in client.<locals>.wrapper(*args, **kwargs)
#    1367 if logging_obj:
#    1368     logging_obj.failure_handler(
#    1369         e, traceback_exception, start_time, end_time
#    1370     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1371 raise e
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/utils.py:1244, in client.<locals>.wrapper(*args, **kwargs)
#    1242         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1243 # MODEL CALL
# -> 1244 result = original_function(*args, **kwargs)
#    1245 end_time = datetime.datetime.now()
#    1246 if _is_streaming_request(
#    1247     kwargs=kwargs,
#    1248     call_type=call_type,
#    1249 ):
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/main.py:3767, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3764     return response
#    3765 except Exception as e:
#    3766     ## Map to OpenAI Exception
# -> 3767     raise exception_type(
#    3768         model=model,
#    3769         custom_llm_provider=custom_llm_provider,
#    3770         original_exception=e,
#    3771         completion_kwargs=args,
#    3772         extra_kwargs=kwargs,
#    3773     )
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2273, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2271 if exception_mapping_worked:
#    2272     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2273     raise e
#    2274 else:
#    2275     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~/projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:1330, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    1328 if original_exception.status_code == 404:
#    1329     exception_mapping_worked = True
# -> 1330     raise NotFoundError(
#    1331         message=f"{custom_llm_provider.capitalize()}Exception - {error_str}",
#    1332         llm_provider=custom_llm_provider,
#    1333         model=model,
#    1334     )
#    1335 if original_exception.status_code == 408:
#    1336     exception_mapping_worked = True
#
# NotFoundError: litellm.NotFoundError: GeminiException - {
#   "error": {
#     "code": 404,
#     "message": "models/gemini-1.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.",
#     "status": "NOT_FOUND"
#   }
# }

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
